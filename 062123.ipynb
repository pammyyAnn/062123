# %% [markdown]
# <a href="https://colab.research.google.com/github/pammyyAnn/062123/blob/main/062123.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
dp_colm = pd.read_csv('/content/drive/MyDrive/FINAL_ACT1_PAM/movies_metadata.csv',
                      usecols=['genres', 'homepage', 'id', 'status', 'title', 'revenue'],
                      index_col='genres')

# %%
dp_colm.head()
# Out:
#                                                                                 homepage  \
# genres
# [{'id': 16, 'name': 'Animation'}, {'id': 35, 'n...  http://toystory.disney.com/toy-story
# [{'id': 12, 'name': 'Adventure'}, {'id': 14, 'n...                                   NaN
# [{'id': 10749, 'name': 'Romance'}, {'id': 35, '...                                   NaN
# [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name...                                   NaN
# [{'id': 35, 'name': 'Comedy'}]                                                       NaN
#
#                                                        id      revenue  \
# genres
# [{'id': 16, 'name': 'Animation'}, {'id': 35, 'n...    862  373554033.0
# [{'id': 12, 'name': 'Adventure'}, {'id': 14, 'n...   8844  262797249.0
# [{'id': 10749, 'name': 'Romance'}, {'id': 35, '...  15602          0.0
# [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name...  31357   81452156.0
# ...

# %%
df_rename = dp_colm.rename(columns={
    'genres': 'GENRES',
    'homepage': 'HOMEPAGE',
    'id': 'ID',
    'revenue': 'REVENUE',
    'status': 'STATUS',
    'title': 'TITLE'
})

# %%
df_rename.head()
# Out:
#                                                                                 HOMEPAGE  \
# genres
# [{'id': 16, 'name': 'Animation'}, {'id': 35, 'n...  http://toystory.disney.com/toy-story
# [{'id': 12, 'name': 'Adventure'}, {'id': 14, 'n...                                   NaN
# [{'id': 10749, 'name': 'Romance'}, {'id': 35, '...                                   NaN
# [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name...                                   NaN
# [{'id': 35, 'name': 'Comedy'}]                                                       NaN
#
#                                                        ID      REVENUE  \
# genres
# [{'id': 16, 'name': 'Animation'}, {'id': 35, 'n...    862  373554033.0
# [{'id': 12, 'name': 'Adventure'}, {'id': 14, 'n...   8844  262797249.0
# [{'id': 10749, 'name': 'Romance'}, {'id': 35, '...  15602          0.0
# [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name...  31357   81452156.0
# ...

# %%
df_drop=df_rename.drop(columns=['HOMEPAGE'])
df_drop.head()
# Out:
#                                                        ID      REVENUE  \
# genres
# [{'id': 16, 'name': 'Animation'}, {'id': 35, 'n...    862  373554033.0
# [{'id': 12, 'name': 'Adventure'}, {'id': 14, 'n...   8844  262797249.0
# [{'id': 10749, 'name': 'Romance'}, {'id': 35, '...  15602          0.0
# [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name...  31357   81452156.0
# [{'id': 35, 'name': 'Comedy'}]                      11862   76578911.0
#
#                                                       STATUS  \
# genres
# [{'id': 16, 'name': 'Animation'}, {'id': 35, 'n...  Released
# [{'id': 12, 'name': 'Adventure'}, {'id': 14, 'n...  Released
# [{'id': 10749, 'name': 'Romance'}, {'id': 35, '...  Released
# [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name...  Released
# [{'id': 35, 'name': 'Comedy'}]                      Released
#
#                                                                           TITLE
# genres
# ...

# %%
del df_drop['ID']
df_drop.head()
# Out:
#                                                         REVENUE    STATUS  \
# genres
# [{'id': 16, 'name': 'Animation'}, {'id': 35, 'n...  373554033.0  Released
# [{'id': 12, 'name': 'Adventure'}, {'id': 14, 'n...  262797249.0  Released
# [{'id': 10749, 'name': 'Romance'}, {'id': 35, '...          0.0  Released
# [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name...   81452156.0  Released
# [{'id': 35, 'name': 'Comedy'}]                       76578911.0  Released
#
#                                                                           TITLE
# genres
# [{'id': 16, 'name': 'Animation'}, {'id': 35, 'n...                    Toy Story
# [{'id': 12, 'name': 'Adventure'}, {'id': 14, 'n...                      Jumanji
# [{'id': 10749, 'name': 'Romance'}, {'id': 35, '...             Grumpier Old Men
# [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name...            Waiting to Exhale
# [{'id': 35, 'name': 'Comedy'}]                      Father of the Bride Part II
